# %%
# !pip install openpyxl
# Out:
# ...
#      |████████████████████████████████| 243 kB 4.3 MB/s eta 0:00:01
# ...

# %%
import pandas as pd

df = pd.read_csv("dataset.csv")
print(df.Hemoglobin)
# Out:
# 0                      NaN
# 1       -0,022340267896652
# 2                      NaN
# 3                      NaN
# 4                      NaN
#                ...
# 5639                   NaN
# 5640                   NaN
# 5641                   NaN
# 5642                   NaN
# 5643     0,541563928127289
# Name: Hemoglobin, Length: 5644, dtype: object
